# %% [markdown]
# <a href="https://colab.research.google.com/github/yandri918/Belajar-python/blob/main/Latihan_table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x = [1,3,5,7,9,10]
y = [2,4,6,8,12,17]

# %%
plt.plot(x,y)
plt.title("tampilan line")
plt.xlabel("sumbu x")
plt.ylabel("sumbu y")
plt.show()

# %%
import matplotlib.pyplot as plt
Angka = ["a","b","c","d","e"]
Nilai = [12,23,3,5,8]
plt.bar(Angka,Nilai)
plt.title("membuat bar")
plt.xlabel("angka")
plt.ylabel("Nilai")
plt.show()

# %%
kategori= ["gambar a", "gambar b", "gambar c"]
ukuran = [ 20,30,50]
plt.pie(ukuran , labels= kategori, autopct ='%1.0f%%')
plt.title(" pie chart")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.random.randn(100)
plt.hist(data,bins= 30, edgecolor= "black")
plt.title(" latihan histogram")
plt.xlabel("angka")
plt.ylabel("frekuensi kemunculan ")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.randn(50)
y = 2*x +1+0.1*np.random.randn(50)
plt.scatter(x,y)
plt.title("latihan scatter")
plt.xlabel(" sumbu x")
plt.ylabel(" sumbu y")
plt.show()

# %%
import seaborn as sns
import numpy as np
data =[ np.random.normal(0 , std,100) for std in range(1,5)]
sns.boxplot(data = data)
plt.title ( " materi boxplot")
plt.xlabel (" kategori")
plt.ylabel ( " nilai")
plt.show()

# %%
import seaborn as sns
import numpy as np
data =[ np.random.normal(0 , std,100) for std in range(4,8)]
sns.violinplot(data = data)
plt.title ( " materi violin plot")
plt.xlabel (" kategori")
plt.ylabel ( " nilai")
plt.show()

# %%
import seaborn as sns
import numpy as np
data = np.random.randn(5,5)
sns.heatmap (data, annot= True)
plt.title( "latihan")
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y1 = [10, 15, 25, 30, 35]
y2 = [5, 10, 20, 25, 30]
plt.fill_between(x, y1,y2,color="red",alpha = 0.4)
plt.title ( " Area chart")
plt.xlabel("sumbu x")
plt.ylabel("sumbu y")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = np.array([' A', ' B', ' C', ' D', ' E'])
data = np.array([6, 5, 3, 4, 9])
angles = np.linspace (0,2*np.pi,len(labels),endpoint= False)
data = np.concatenate((data ,[data[0]]))
angles =np.concatenate((angles,[angles[0]]))
plt.polar (angles , data , marker= 'o')
plt.fill(angles, data ,alpha = 0.25)
plt.title (" radar chart")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = np.array([' A', ' B', ' C', ' D', ' E'])
data = np.array([4, 5, 3, 4, 2])

angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False)
data = np.concatenate((data, [data[0]]))
angles = np.concatenate((angles, [angles[0]]))

plt.polar(angles, data, marker='o')
plt.fill(angles, data, alpha=0.25)
plt.title('Radar Chart')
plt.show()
